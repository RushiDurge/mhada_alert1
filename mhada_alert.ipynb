# %%
import requests
import time

# %%
BOT_TOKEN = "8626839458:AAG6zFHJafiAfLhs1B4xhrZ6phTqMHcVYoc"
CHAT_ID = "1878285104"

def send_telegram(msg):
    url = f"https://api.telegram.org/bot{BOT_TOKEN}/sendMessage"
    data = {"chat_id": CHAT_ID, "text": msg}
    requests.post(url, data=data)

# %%
URL = "https://bookmyhome.mhada.gov.in/app/select-scheme/3/161/APPLY"
previous_data = ""
while True:
    try:
        response = requests.get(URL)
        data = response.text
        # Simple check (you can improve logic later)
        if "Available" in data and data != previous_data:
            send_telegram("⚡ MHADA Alert: New flats may be available! Check now!")
            previous_data = data
        print("Checking...")
        time.sleep(60)  # check every 1 minute
    except Exception as e:
        print("Error:", e)
        time.sleep(60)
# Out:
# Checking...
# Checking...
# Checking...

# %%
# !pip install requests
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Admin\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Admin\anaconda3\Lib\site-packages)
